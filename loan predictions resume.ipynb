# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
s=pd.read_csv('t1train.csv')
s.drop(['Loan_ID'],inplace=True,axis=1)

# %%
s
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
s.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
s['Gender'].fillna(s['Gender'].mode()[0],inplace=True)

# %%
s['Credit_History'].fillna(s['Credit_History'].mode()[0],inplace=True)

# %%
s['Dependents'].fillna(s['Dependents'].mode()[0],inplace=True)

# %%
s['Self_Employed'].fillna(s['Self_Employed'].mode()[0],inplace=True)

# %%
s['LoanAmount'].fillna(
    
    value=128.0,
    axis=0,
    inplace=True,
    )

# %%
s
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
s['Loan_Amount_Term'].fillna(s['Loan_Amount_Term'].mode()[0],inplace=True)

# %%
s
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
s['Married']=pd.get_dummies(s['Married'],drop_first=True)
s['Education']=pd.get_dummies(s['Education'],drop_first=True)
s['Self_Employed']=pd.get_dummies(s['Self_Employed'],drop_first=True)
s['Property_Area']=pd.get_dummies(s['Property_Area'],drop_first=True)
s['Credit_History']=pd.get_dummies(s['Credit_History'],drop_first=True)
s['Dependents']=pd.get_dummies(s['Dependents'],drop_first=True)
s['Gender']=pd.get_dummies(s['Gender'],drop_first=True)

# %%
s
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           0          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           0          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
s.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
s['Total_income']=s['ApplicantIncome']+s['CoapplicantIncome']

# %%
s['EMI']=(s['LoanAmount']*0.09*(1.09**s['Loan_Amount_Term']))/(1.09**(s['Loan_Amount_Term']-1))

# %%
s.drop(['ApplicantIncome','CoapplicantIncome'],axis=1,inplace=True)

# %%
s
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          0              0       128.0
# 1         1        1           1          0              0       128.0
# 2         1        1           0          0              1        66.0
# 3         1        1           0          1              0       120.0
# 4         1        0           0          0              0       141.0
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          0              0        71.0
# 610       1        1           0          0              0        40.0
# 611       1        1           1          0              0       253.0
# 612       1        1           0          0              0       187.0
# 613       0        0           0          0              1       133.0
#
#      Loan_Amount_Term  Credit_History  Property_Area Loan_Status  \
# ...

# %%
test=pd.read_csv('s11.csv')

# %%
test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        1           0          0              0       110.0
# 1         1        1           1          0              0       126.0
# 2         1        1           0          0              0       208.0
# 3         1        1           0          0              0       100.0
# 4         1        0           0          1              0        78.0
# ..      ...      ...         ...        ...            ...         ...
# 362       1        1           0          1              1       113.0
# 363       1        1           0          0              0       115.0
# 364       1        0           0          0              0       126.0
# 365       1        1           0          0              0       158.0
# 366       1        0           0          0              1        98.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_income      EMI
# ...

# %%
final=pd.concat([s,test],axis=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
final=final.loc[:,~final.columns.duplicated()]

# %%
s
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          0              0       128.0
# 1         1        1           1          0              0       128.0
# 2         1        1           0          0              1        66.0
# 3         1        1           0          1              0       120.0
# 4         1        0           0          0              0       141.0
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          0              0        71.0
# 610       1        1           0          0              0        40.0
# 611       1        1           1          0              0       253.0
# 612       1        1           0          0              0       187.0
# 613       0        0           0          0              1       133.0
#
#      Loan_Amount_Term  Credit_History  Property_Area Loan_Status  \
# ...

# %%
test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        1           0          0              0       110.0
# 1         1        1           1          0              0       126.0
# 2         1        1           0          0              0       208.0
# 3         1        1           0          0              0       100.0
# 4         1        0           0          1              0        78.0
# ..      ...      ...         ...        ...            ...         ...
# 362       1        1           0          1              1       113.0
# 363       1        1           0          0              0       115.0
# 364       1        0           0          0              0       126.0
# 365       1        1           0          0              0       158.0
# 366       1        0           0          0              1        98.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_income      EMI
# ...

# %%
X = s.drop(['Loan_Status'],axis=1)
y = s['Loan_Status']

# %%
X.shape
# Out:
# (614, 11)

# %%
y.shape
# Out:
# (614,)

# %%
test.shape
# Out:
# (367, 11)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,y_train)
predictions = model.predict(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7a6915396ee> in <module>
#       1 from sklearn.svm import SVC
#       2 model = SVC()
# ----> 3 model.fit(X_train,y_train)
#       4 predictions = model.predict(test)
#
# NameError: name 'X_train' is not defined

# %%
#from sklearn.tree import DecisionTreeClassifier
#dtree = DecisionTreeClassifier(criterion='gini')
#dtree.fit(X_train,y_train)
#predictions1 = dtree.predict(test)

# %%
#from sklearn.neighbors import KNeighborsClassifier
#knn = KNeighborsClassifier(n_neighbors=1)
#knn.fit(X_train,y_train)
#pred = knn.predict(test)

# %%
#predictions

# %%
#predictions.shape

# %%
#predictions

# %%
#dataframe=pd.DataFrame(predictions, columns=['Loan_Status'])

# %%
#dataframe

# %%
#dataframe.to_csv('sss.csv',index=False)

# %%
#from sklearn import metrics

# %%
#predictions

# %%
test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        1           0          0              0       110.0
# 1         1        1           1          0              0       126.0
# 2         1        1           0          0              0       208.0
# 3         1        1           0          0              0       100.0
# 4         1        0           0          1              0        78.0
# ..      ...      ...         ...        ...            ...         ...
# 362       1        1           0          1              1       113.0
# 363       1        1           0          0              0       115.0
# 364       1        0           0          0              0       126.0
# 365       1        1           0          0              0       158.0
# 366       1        0           0          0              1        98.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_income      EMI
# ...

# %%
y_test
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
#       ..
# 380    Y
# 446    Y
# 144    Y
# 290    Y
# 353    N
# Name: Loan_Status, Length: 185, dtype: object

# %%
X_test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 350       1        1           0          0              0       228.0
# 377       1        1           0          0              0       130.0
# 163       1        1           0          0              0       158.0
# 609       0        0           0          0              0        71.0
# 132       1        0           0          0              0        70.0
# ..      ...      ...         ...        ...            ...         ...
# 380       1        1           0          0              0       128.0
# 446       1        1           0          1              0       110.0
# 144       1        1           0          0              0       187.0
# 290       1        1           0          0              0       139.0
# 353       0        1           0          0              1       105.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_income      EMI
# ...

# %%
#hyperparameter tuning

# %%
#logmodel=LogisticRegression()

# %%
#from sklearn.metrics import classification_report

# %%
#print(classification_report(y_test,predictions))

# %%
#logmodel.fit(X_train, y_train)
#print("model score: %.3f" % logmodel.score(X_test, y_test))

# %%
X_train
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 553       1        1           0          1              0       181.0
# 601       1        1           0          1              0       155.0
# 261       1        0           0          0              0       134.0
# 496       1        1           0          1              0       107.0
# 529       1        0           0          1              0       130.0
# ..      ...      ...         ...        ...            ...         ...
# 71        1        1           0          1              1        97.0
# 106       1        1           0          0              0       225.0
# 270       0        0           0          0              0        30.0
# 435       0        0           0          0              0       128.0
# 102       1        1           0          0              0       128.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_income      EMI
# ...

# %%
y_train
# Out:
# 553    N
# 601    Y
# 261    Y
# 496    Y
# 529    Y
#       ..
# 71     Y
# 106    Y
# 270    Y
# 435    Y
# 102    Y
# Name: Loan_Status, Length: 429, dtype: object

# %%
X_test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 350       1        1           0          0              0       228.0
# 377       1        1           0          0              0       130.0
# 163       1        1           0          0              0       158.0
# 609       0        0           0          0              0        71.0
# 132       1        0           0          0              0        70.0
# ..      ...      ...         ...        ...            ...         ...
# 380       1        1           0          0              0       128.0
# 446       1        1           0          1              0       110.0
# 144       1        1           0          0              0       187.0
# 290       1        1           0          0              0       139.0
# 353       0        1           0          0              1       105.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_income      EMI
# ...

# %%
y_test
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
#       ..
# 380    Y
# 446    Y
# 144    Y
# 290    Y
# 353    N
# Name: Loan_Status, Length: 185, dtype: object

# %%
y_train
# Out:
# 553    N
# 601    Y
# 261    Y
# 496    Y
# 529    Y
#       ..
# 71     Y
# 106    Y
# 270    Y
# 435    Y
# 102    Y
# Name: Loan_Status, Length: 429, dtype: object

# %%
#predictions

# %%
y_test
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
#       ..
# 380    Y
# 446    Y
# 144    Y
# 290    Y
# 353    N
# Name: Loan_Status, Length: 185, dtype: object

# %%
#logModel = LogisticRegression()

# %%
#param_grid = [    
 #   {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
  #  'C' : np.logspace(-4, 4, 20),
   # 'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    #'max_iter' : [100, 1000,2500, 5000]
    #}
#]





#Init signature:
#LogisticRegression(
#    penalty='l2',
#    dual=False,
#    tol=0.0001,
#    C=1.0,
#    fit_intercept=True,
#    intercept_scaling=1,
#    class_weight=None,
#    random_state=None,
#    solver='lbfgs',
#    max_iter=100,
#    multi_class='auto',
#    verbose=0,
#    warm_start=False,
#    n_jobs=None,
#    l1_ratio=None,

# %%
#from sklearn.model_selection import GridSearchCV

# %%
#clf = GridSearchCV(logModel, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
#best_clf = clf.fit(X,y)

# %%
#best_clf.best_estimator_

# %%
#print (f'Accuracy - : {best_clf.score(X,y):.3f}')

# %%
#predic=best_clf.predict(test)

# %%
#predic

# %%
#pre=pd.DataFrame(predictions)
#sub_df=pd.read_csv('s1traintest.csv')
#datasets=pd.concat([sub_df['Loan_ID'],pre],axis=1)
#datasets.columns=['Loan_ID','Loan_Status']
#datasets.to_csv('go22.csv',index=False)

# %%
#cpre=pd.DataFrame(predic)
#sub_df1=pd.read_csv('s1traintest.csv')
#datasets1=pd.concat([sub_df['Loan_ID'],cpre],axis=1)
#datasets1.columns=['Loan_ID','Loan_Status']
#datasets1.to_csv('go33.csv',index=False)

# %%
#pred

# %%
#pro=pd.DataFrame(pred)
#sub_df2=pd.read_csv('s1traintest.csv')
#datasets1=pd.concat([sub_df2['Loan_ID'],pro],axis=1)
#datasets1.columns=['Loan_ID','Loan_Status']
#datasets1.to_csv('gotit.csv',index=False)

# %%
#pro1=pd.DataFrame(predictions1)
#sub_df2=pd.read_csv('s1traintest.csv')
#datasets1=pd.concat([sub_df2['Loan_ID'],pro1],axis=1)
#datasets1.columns=['Loan_ID','Loan_Status']
datasets1.to_csv('gee1.csv',index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=10000)
rfc.fit(X_train,y_train)
predictions2 = rfc.predict(test)

# %%
pro4=pd.DataFrame(predictions1)
sub_df2=pd.read_csv('s1traintest.csv')
datasets1=pd.concat([sub_df2['Loan_ID'],pro4],axis=1)
datasets1.columns=['Loan_ID','Loan_Status']
datasets1.to_csv('gee222.csv',index=False)
